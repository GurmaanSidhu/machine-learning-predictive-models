# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("dt.csv")
numeric_df = df.select_dtypes(include=['int64','float64'])
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=0)
    kmeans.fit(numeric_df)
    wcss.append(kmeans.inertia_)  # inertia_ = wcss

# %%
plt.figure(figsize = (8,5))
plt.plot(range(1,11),wcss, marker='o')
plt.title('Elbow method to determine optimal number of cluster')
plt.xlabel("Number of clusters (K)")
plt.ylabel('WCSS')
plt.grid()
plt.show()

# %%
# wcss values
print("WCSS values for each k=1 to 10")
for i, val in enumerate(wcss,1):
    print(f"k = {i} -> wcss = {val}")
# Out:
# WCSS values for each k=1 to 10
# k = 1 -> wcss = 274448589.96179235
# k = 2 -> wcss = 70153166.31637955
# k = 3 -> wcss = 43769323.60776102
# k = 4 -> wcss = 20892291.549562436
# k = 5 -> wcss = 14020721.24579953
# k = 6 -> wcss = 9816255.32060493
# k = 7 -> wcss = 8817200.459547954
# k = 8 -> wcss = 5501269.523952356
# k = 9 -> wcss = 4716628.294896566
# k = 10 -> wcss = 3861190.3992751446
