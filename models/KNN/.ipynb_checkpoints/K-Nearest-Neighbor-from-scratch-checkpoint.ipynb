# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter

# %%
data = pd.read_csv("data.csv")

X = data.drop(columns=['id','diagnosis']).values
y = data['diagnosis'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (455, 31)
# X_test shape: (114, 31)
# y_train shape: (455,)
# y_test shape: (114,)

# %%
plt.scatter(X_train[y_train == 'B', 0], X_train[y_train == 'B', 1], color = 'tab:green', label = 'Bengin')
plt.scatter(X_train[y_train == 'M', 0], X_train[y_train == 'M', 1], color = 'tab:red', label = 'Malignant')
plt.xlabel('Radius Mean')
plt.ylabel('Texture Mean')
plt.legend()
plt.show()

# %%
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) **2))

# %%
class KNN:
    def __init__(self, k):
        self.k = k

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, new_points):
        predictions = [self.predict_class[new_point] for new_point in new_points]
        return np.array(predictions)

    def predict_class(self, new_points):
        distances = [euclidean_distance(point, new_point) for point in self.X_trai]

        k_nearest_indicies = np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_nearest_indices]

        most_common = Counter(k_nearest_labels).most_common(1)[0][0]

        return most_common

# %%
knn = KNN(5)
knn.fit(X_train, y_train)
predictions = knn.predict(X_test)
accuracy = np.mean(predictions == y_test) * 100
print(f"Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 knn = KNN(5)
#       2 knn.fit(X_train, y_train)
# ----> 3 predictions = knn.predict(X_test)
#       4 accuracy = np.mean(predictions == y_test) * 100
#       5 print(f"Accuracy: {accuracy:.2f}")
#
# Cell In[14], line 10, in KNN.predict(self, new_points)
#       9 def predict(self, new_points):
# ---> 10     predictions = [self.predict_class[new_point] for new_point in new_points]
#      11     return np.array(predictions)
#
# TypeError: 'method' object is not subscriptable
